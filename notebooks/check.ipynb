# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import matplotlib.pyplot as plt
sys.path.append('../')
from cv_toolkit.metrics import psnr, ssim

# %%
from skimage.data import chelsea

# %%
img = chelsea()
plt.imshow(img)

# %%
before = img.copy()
psnr(img, img)
# Out:
# inf

# %%
from skimage.util import img_as_float

# %%
assert psnr(img, img) == float('inf'), "Something went wrong PSNR"
assert ssim(img, img) == 1., "Something went wrong with SSIM"

# %%
from cv_toolkit.utils.utils import add_noise

# %%
img = img_as_float(chelsea())
print(img.max())
noisy_img = add_noise(img, noise_type="gaussian", intensity=0.1)
print(img.max())
plt.imshow(noisy_img)
# Out:
# 0.9058823529411765
# 0.9058823529411765

# %%
from skimage.util import img_as_ubyte

# %%
ssim(img_as_ubyte(img), img_as_ubyte(noisy_img))
# Out:
# 0.27289025214137

# %%
plt.imshow(img)

# %%
img_as_float(img_as_float(img)).min()
# Out:
# 0.0

# %%
psnr(img, noisy_img)
# Out:
# 6.380276127831762

# %%
ssim(img, noisy_img)
# Out:
# 0.004857867006309813

# %%
from cv_toolkit.utils.processing import load_image

# %%
img, _ = load_image('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8NEXqCwgebMpV7WiH_Z81h8Vc7eyS8kz0nNM-QlNh&s')
